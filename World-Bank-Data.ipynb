# %%
# LIBRARIES 
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('World Bank data on Countries.csv');

# %%
df
# Out:
#      Country Name Country Code  Year  Agriculture (% GDP)  \
# 0     Afghanistan          AFG  2000            27.501127
# 1     Afghanistan          AFG  2001            27.501127
# 2     Afghanistan          AFG  2002            38.627892
# 3     Afghanistan          AFG  2003            37.418855
# 4     Afghanistan          AFG  2004            29.721067
# ...           ...          ...   ...                  ...
# 5101     Zimbabwe          ZWE  2018             7.319375
# 5102     Zimbabwe          ZWE  2019             9.819262
# 5103     Zimbabwe          ZWE  2020             8.772859
# 5104     Zimbabwe          ZWE  2021             8.849899
# 5105     Zimbabwe          ZWE  2022            12.069543
#
#       Ease of Doing Business  Education Expenditure (% GDP)  Export (% GDP)  \
# 0                  40.717968                      13.670101             NaN
# 1                  40.717968                      13.670101             NaN
# ...

# %%
df = df[['Country Name', 'Year','GDP','Population','Continent Name','Export','Import','Health Expenditure','Net Trade']]

# %%
df
# Out:
#      Country Name  Year           GDP  Population Continent Name  \
# 0     Afghanistan  2000  1.415197e+10  19542982.0           Asia
# 1     Afghanistan  2001  1.415197e+10  19688632.0           Asia
# 2     Afghanistan  2002  3.854235e+09  21000256.0           Asia
# 3     Afghanistan  2003  4.539497e+09  22645130.0           Asia
# 4     Afghanistan  2004  5.220825e+09  23553551.0           Asia
# ...           ...   ...           ...         ...            ...
# 5101     Zimbabwe  2018  3.415607e+10  15052184.0         Africa
# 5102     Zimbabwe  2019  2.183223e+10  15354608.0         Africa
# 5103     Zimbabwe  2020  2.150970e+10  15669666.0         Africa
# 5104     Zimbabwe  2021  2.837124e+10  15993524.0         Africa
# 5105     Zimbabwe  2022  2.067806e+10  16320537.0         Africa
#
#             Export        Import  Health Expenditure     Net Trade
# 0              NaN           NaN        1.542930e+09           NaN
# ...

# %%
df.isna().sum()
# Out:
# Country Name            0
# Year                    0
# GDP                    69
# Population              0
# Continent Name          0
# Export                460
# Import                460
# Health Expenditure    575
# Net Trade             460
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_7088\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Country Name          0
# Year                  0
# GDP                   0
# Population            0
# Continent Name        0
# Export                0
# Import                0
# Health Expenditure    0
# Net Trade             0
# dtype: int64

# %%
df
# Out:
#      Country Name  Year           GDP  Population Continent Name  \
# 23        Albania  2000  3.480355e+09   3089027.0         Europe
# 24        Albania  2001  3.922101e+09   3060173.0         Europe
# 25        Albania  2002  4.348068e+09   3051010.0         Europe
# 26        Albania  2003  5.611496e+09   3039616.0         Europe
# 27        Albania  2004  7.184686e+09   3026939.0         Europe
# ...           ...   ...           ...         ...            ...
# 5101     Zimbabwe  2018  3.415607e+10  15052184.0         Africa
# 5102     Zimbabwe  2019  2.183223e+10  15354608.0         Africa
# 5103     Zimbabwe  2020  2.150970e+10  15669666.0         Africa
# 5104     Zimbabwe  2021  2.837124e+10  15993524.0         Africa
# 5105     Zimbabwe  2022  2.067806e+10  16320537.0         Africa
#
#             Export        Import  Health Expenditure     Net Trade
# 23    7.000834e+08  1.508344e+09        2.068788e+08 -8.082604e+08
# ...

# %%
df_Europe=df[df['Continent Name'] == 'Europe']
df_North_America=df[df['Continent Name'] == 'North America']
df_South_America=df[df['Continent Name'] == 'South America']
df_Oceania=df[df['Continent Name'] == 'Oceania']
df_Africa=df[df['Continent Name'] == 'Africa']
df_Asia=df[df['Continent Name'] == 'Asia']

# %%
df_Europe
# Out:
#         Country Name  Year           GDP  Population Continent Name  \
# 23           Albania  2000  3.480355e+09   3089027.0         Europe
# 24           Albania  2001  3.922101e+09   3060173.0         Europe
# 25           Albania  2002  4.348068e+09   3051010.0         Europe
# 26           Albania  2003  5.611496e+09   3039616.0         Europe
# 27           Albania  2004  7.184686e+09   3026939.0         Europe
# ...              ...   ...           ...         ...            ...
# 4848  United Kingdom  2018  2.878152e+12  66460344.0         Europe
# 4849  United Kingdom  2019  2.857058e+12  66836327.0         Europe
# 4850  United Kingdom  2020  2.704609e+12  67081234.0         Europe
# 4851  United Kingdom  2021  3.122480e+12  67026300.0         Europe
# 4852  United Kingdom  2022  3.070668e+12  66971411.0         Europe
#
#             Export        Import  Health Expenditure     Net Trade
# 23    7.000834e+08  1.508344e+09        2.068788e+08 -8.082604e+08
# ...

# %%
df_Africa
# Out:
#      Country Name  Year           GDP  Population Continent Name  \
# 46        Algeria  2000  5.479040e+10  30774621.0         Africa
# 47        Algeria  2001  5.474470e+10  31200985.0         Africa
# 48        Algeria  2002  5.676036e+10  31624696.0         Africa
# 49        Algeria  2003  6.786385e+10  32055883.0         Africa
# 50        Algeria  2004  8.533258e+10  32510186.0         Africa
# ...           ...   ...           ...         ...            ...
# 5101     Zimbabwe  2018  3.415607e+10  15052184.0         Africa
# 5102     Zimbabwe  2019  2.183223e+10  15354608.0         Africa
# 5103     Zimbabwe  2020  2.150970e+10  15669666.0         Africa
# 5104     Zimbabwe  2021  2.837124e+10  15993524.0         Africa
# 5105     Zimbabwe  2022  2.067806e+10  16320537.0         Africa
#
#             Export        Import  Health Expenditure     Net Trade
# 46    2.305017e+10  1.139017e+10        1.911655e+09  1.166000e+10
# ...

# %%
df_Asia
# Out:
#      Country Name  Year           GDP  Population Continent Name  \
# 185       Armenia  2000  1.911564e+09   3168523.0           Asia
# 187       Armenia  2001  2.118468e+09   3133133.0           Asia
# 189       Armenia  2002  2.376335e+09   3105037.0           Asia
# 191       Armenia  2003  2.807061e+09   3084102.0           Asia
# 193       Armenia  2004  3.576615e+09   3065745.0           Asia
# ...           ...   ...           ...         ...            ...
# 5055  Yemen, Rep.  2018  2.160616e+10  30790513.0           Asia
# 5056  Yemen, Rep.  2019  2.474992e+10  31546691.0           Asia
# 5057  Yemen, Rep.  2020  2.474992e+10  32284046.0           Asia
# 5058  Yemen, Rep.  2021  2.474992e+10  32981641.0           Asia
# 5059  Yemen, Rep.  2022  2.474992e+10  33696614.0           Asia
#
#             Export        Import  Health Expenditure     Net Trade
# 185   4.236296e+08  9.571565e+08        8.020561e+07 -5.335268e+08
# ...

# %%
df_Oceania
# Out:
#      Country Name  Year           GDP  Population Continent Name  \
# 253     Australia  2000  4.158450e+11  19028802.0        Oceania
# 254     Australia  2001  3.793578e+11  19274701.0        Oceania
# 255     Australia  2002  3.955730e+11  19495210.0        Oceania
# 256     Australia  2003  4.674980e+11  19720737.0        Oceania
# 257     Australia  2004  6.143264e+11  19932722.0        Oceania
# ...           ...   ...           ...         ...            ...
# 4940      Vanuatu  2018  9.147370e+08    297298.0        Oceania
# 4941      Vanuatu  2019  9.365263e+08    304404.0        Oceania
# 4942      Vanuatu  2020  9.094210e+08    311685.0        Oceania
# 4943      Vanuatu  2021  9.716361e+08    319137.0        Oceania
# 4944      Vanuatu  2022  9.835829e+08    326740.0        Oceania
#
#             Export        Import  Health Expenditure     Net Trade
# 253   8.069588e+10  8.966328e+10        3.160262e+10 -8.967395e+09
# ...

# %%
df_South_America
# Out:
#        Country Name  Year           GDP  Population Continent Name  \
# 161       Argentina  2000  2.842038e+11  37070774.0  South America
# 162       Argentina  2001  2.686968e+11  37480493.0  South America
# 163       Argentina  2002  9.772400e+10  37885028.0  South America
# 164       Argentina  2003  1.275870e+11  38278164.0  South America
# 165       Argentina  2004  1.646579e+11  38668796.0  South America
# ...             ...   ...           ...         ...            ...
# 4963  Venezuela, RB  2018  2.452296e+11  29825653.0  South America
# 4964  Venezuela, RB  2019  2.452296e+11  28971683.0  South America
# 4965  Venezuela, RB  2020  2.452296e+11  28490453.0  South America
# 4966  Venezuela, RB  2021  2.452296e+11  28199867.0  South America
# 4967  Venezuela, RB  2022  2.452296e+11  28301696.0  South America
#
#             Export        Import  Health Expenditure     Net Trade
# 161   3.122369e+10  3.307015e+10        2.336158e+10 -1.846456e+09
# ...

# %%
df_North_America
# Out:
#              Country Name  Year           GDP   Population Continent Name  \
# 138   Antigua and Barbuda  2000  8.263704e+08      75055.0  North America
# 139   Antigua and Barbuda  2001  8.004815e+08      76215.0  North America
# 140   Antigua and Barbuda  2002  8.143815e+08      77195.0  North America
# 141   Antigua and Barbuda  2003  8.563963e+08      78075.0  North America
# 142   Antigua and Barbuda  2004  9.197296e+08      78941.0  North America
# ...                   ...   ...           ...          ...            ...
# 4871        United States  2018  2.053306e+13  326838199.0  North America
# 4872        United States  2019  2.138098e+13  328329953.0  North America
# 4873        United States  2020  2.106047e+13  331511512.0  North America
# 4874        United States  2021  2.331508e+13  332031554.0  North America
# 4875        United States  2022  2.546270e+13  333287557.0  North America
#
#             Export        Import  Health Expenditure     Net Trade
# ...

# %%
df['Continent Name'].unique()
# Out:
# array(['Europe', 'Africa', 'North America', 'South America', 'Asia',
#        'Oceania'], dtype=object)

# %% [markdown]
# #### using for loop

# %%
for i in df['Continent Name'].unique():
    subset = df[df['Continent Name'] == i]
    subset.to_csv(f'{i}.csv', index=False)

# %%
df.to_csv('Clean Data.csv',index=False)

# %% [markdown]
# ## The End
